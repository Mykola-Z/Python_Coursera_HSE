# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb 10 19:53:33 2020

@author: mzly903
"""
matches = []

len_mat = []

all_points = []

lefts = []

rights = []
for i in range(3):
    l = int(input())
    r = int(input())
    
    matches.append(l)
    matches.append(r)
    
    lefts.append(l)
    rights.append(r)
    for j in range(l, r):
        
        all_points.append(j)

d['1'] = {lefts[0], rigth[0]}
d['2'] = {lefts[1], rigth[1]}
d['3'] = {lefts[2], rigth[2]}

d = sort[d]
print(d)
all_points = list(set(all_points))

min_value = min(all_points)
max_value = max(all_points)


gap = []
check = 0
for t in range(min_value, max_value + 1):
    if t not in all_points:
        
        check = 1
        
        gap.append(t+0.5)
    
if check == 0:
    print(check)
else:
    lefts = sorted(lefts)
    rigths = sorted(rights)
    p0 = False
    p2 = False
    if rights[1]+rights[0] - lefts[0] >= lefts[2]:
        p0 = True
    if rights[0]+rights[2] - lefts[0] >= lefts[2]:
        p2 = True
    if (p0 and p2):
        print("MIN somthing")
    elif p0:
        print(d)
